# %% [markdown]
# Comparing the Ratings of the Apps between the Google Play Store and Apple App Store.

# %%
# %matplotlib inline

# %%
# Import Dependencies

import pandas as pd
import numpy as np
from matplotlib import pyplot as plt


import seaborn as sns # for making plots with seaborn
color = sns.color_palette()
sns.set(rc={'figure.figsize':(25,15)})

import plotly
# connected=True means it will download the latest version of plotly javascript library.
plotly.offline.init_notebook_mode(connected=True)
import plotly.graph_objs as go

import warnings
warnings.filterwarnings('ignore')
# Out:
# <script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window.Plotly) {{require(['plotly'],function(plotly) {window.Plotly=plotly;});}}</script>

# %%
# Read in the files
google_data = pd.read_csv('Resources/googleplaystore.csv')
apple_data = pd.read_csv('Resources/AppleStore.csv')

# %%
#Re-organizing dataframe to only display specific columns

google_df = google_data[["App", "Category", "Rating", "Reviews", "Size", "Installs", "Type", "Price", "Genres"]]
apple_df = apple_data[["track_name","size_bytes","price","rating_count_tot","user_rating","prime_genre"]]

# %%
google_df.drop_duplicates(subset='App', inplace=True)
google_df = google_df[google_df['Installs'] != 'Free']
google_df = google_df[google_df['Installs'] != 'Paid']

google_df.head(20)
# Out:
#                                                   App        Category  Rating  \
# 0      Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                 Coloring book moana  ART_AND_DESIGN     3.9
# 2   U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                               Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4               Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
# 5                          Paper flowers instructions  ART_AND_DESIGN     4.4
# 6             Smoke Effect Photo Maker - Smoke Editor  ART_AND_DESIGN     3.8
# 7                                    Infinite Painter  ART_AND_DESIGN     4.1
# 8                                Garden Coloring Book  ART_AND_DESIGN     4.4
# 9                       Kids Paint Free - Drawing Fun  ART_AND_DESIGN     4.7
# 10                            Text on Photo - Fonteee  ART_AND_DESIGN     4.4
# ...

# %% [markdown]
# Data Cleaning
#
# Convert all app sizes to MB Remove '+' from 'Number of Installs' to make it numeric Convert all review text to English language using Google Translator library

# %%
# - Installs : Remove + and ,

google_df['Installs'] = google_df['Installs'].apply(lambda x: x.replace('+', '') if '+' in str(x) else x)
google_df['Installs'] = google_df['Installs'].apply(lambda x: x.replace(',', '') if ',' in str(x) else x)
google_df['Installs'] = google_df['Installs'].apply(lambda x: int(x))

# %%
# Size : Replace 'Varies with device to NaN value Remove 'M', Replace 'k' and divide by 10^-3


google_df['Size'] = google_df['Size'].apply(lambda x: str(x).replace('Varies with device', 'NaN') if 'Varies with device' in str(x) else x)

# Remove 'M' and ',' and 'K'
google_df['Size'] = google_df['Size'].apply(lambda x: str(x).replace('M', '') if 'M' in str(x) else x)
google_df['Size'] = google_df['Size'].apply(lambda x: str(x).replace(',', '') if 'M' in str(x) else x)
google_df['Size'] = google_df['Size'].apply(lambda x: float(str(x).replace('k', '')) / 1000 if 'k' in str(x) else x)
google_df['Size'] = google_df['Size'].apply(lambda x: float(x))

google_df['Installs'] = google_df['Installs'].apply(lambda x: float(x))

# Remove '$'
google_df['Price'] = google_df['Price'].apply(lambda x: str(x).replace('$', '') if '$' in str(x) else str(x))
google_df['Price'] = google_df['Price'].apply(lambda x: float(x))

google_df['Reviews'] = google_df['Reviews'].apply(lambda x: int(x))

# %%
#Renaming the columns and adding "Type" column in order to categorize the free and paid apps

apple_df = apple_df.rename(columns = {"track_name":"App","rating_count_tot":"Rating Count",
                                          "user_rating":"Rating","prime_genre":"Genres","price":"Price"})
apple_df["Size (M)"] = (apple_df["size_bytes"]*(1e-6)).map("{:.1f}".format)
apple_df = apple_df.drop(columns = "size_bytes")
apple_df["Type"]=""
apple_df.loc[apple_df["Price"]==0,["Type"]]="Free"
apple_df.loc[apple_df["Type"]=="",["Type"]]="Paid"
apple_df.head()
# Out:
#                                                  App  Price  Rating Count  \
# 0                                    PAC-MAN Premium   3.99         21292
# 1                          Evernote - stay organized   0.00        161065
# 2    WeatherBug - Local Weather, Radar, Maps, Alerts   0.00        188583
# 3  eBay: Best App to Buy, Sell, Save! Online Shop...   0.00        262241
# 4                                              Bible   0.00        985920
#
#    Rating        Genres Size (M)  Type
# 0     4.0         Games    100.8  Paid
# 1     4.0  Productivity    158.6  Free
# 2     3.5       Weather    100.5  Free
# 3     4.0      Shopping    128.5  Free
# 4     4.5     Reference     92.8  Free

# %% [markdown]
# Look for any evident patterns or relationships between the features.

# %%
x = google_df['Rating'].dropna()
z = google_df['Installs'][google_df.Installs!=0].dropna()
p = google_df['Reviews'][google_df.Reviews!=0].dropna()
t = google_df['Type'].dropna()
price = google_df['Price']

p = sns.pairplot(pd.DataFrame(list(zip(x, np.log(z), np.log10(p), t, price)), 
                        columns=['Rating', 'Installs', 'Reviews', 'Type', 'Price']), hue='Type', palette="Set1")

# %% [markdown]
# Seems like the ratings are higher for paid apps
#
#
# ** Points to keep in mind -There is no total rating count for Google play store, whereas Apple App store has it but App store does not have the number of Installs or reviews.

# %%
apple_df['Rating Count'] = apple_df['Rating Count'].apply(lambda x: float(x))
apple_df['Rating'] = apple_df['Rating'].apply(lambda x: float(x))
apple_df['Price'] = apple_df['Price'].apply(lambda x: float(x))

# %%
x = apple_df['Rating'].dropna()
p = apple_df['Rating Count'][apple_data.rating_count_tot!=0].dropna()
t = apple_df['Type'].dropna()
price = apple_df['Price']

p = sns.pairplot(pd.DataFrame(list(zip(x, np.log10(p), t, price)), 
                        columns=['Rating',  'Rating Count', 'Type', 'Price']), hue = 'Type', palette="Set2")

# %% [markdown]
# Seems like the rating count and ratings are higher for Free apps

# %% [markdown]
# ##Average rating of apps from each store.

# %%
data = [go.Histogram(
        x = google_df.Rating,
        xbins = {'start': 1, 'size': 0.1, 'end' :5}
)]

print('Average app rating = ', np.mean(google_df['Rating']))
plotly.offline.iplot(data, filename='overall_rating_distribution')
# Out:
# Average app rating =  4.173243045387998
# ...

# %%
a_data = [go.Histogram(
        x = apple_df.Rating,
        xbins = {'start': 1, 'size': 0.1, 'end' :5}
)]

print('Average app rating = ', np.mean(apple_df['Rating']))
plotly.offline.iplot(a_data, filename='overall_rating_distribution')
# Out:
# Average app rating =  3.526955675976101
# ...

# %% [markdown]
# Generally, most apps do well with an average rating of 4.17 for the Google Play Store, whereas the average rating for the Apple App store seems to be 3.53.

# %%
#We can break this down even further to inspect if we have categories which perform exceptionally good or bad. In order to do that we will be running a one way ANOVA Test.
#Anova test for the google play store
import scipy.stats as stats
f = stats.f_oneway(google_df.loc[google_df.Category == 'BUSINESS']['Rating'].dropna(), 
               google_df.loc[google_df.Category == 'FAMILY']['Rating'].dropna(),
               google_df.loc[google_df.Category == 'GAME']['Rating'].dropna(),
               google_df.loc[google_df.Category == 'PERSONALIZATION']['Rating'].dropna(),
               google_df.loc[google_df.Category == 'LIFESTYLE']['Rating'].dropna(),
               google_df.loc[google_df.Category == 'FINANCE']['Rating'].dropna(),
               google_df.loc[google_df.Category == 'EDUCATION']['Rating'].dropna(),
               google_df.loc[google_df.Category == 'MEDICAL']['Rating'].dropna(),
               google_df.loc[google_df.Category == 'TOOLS']['Rating'].dropna(),
               google_df.loc[google_df.Category == 'PRODUCTIVITY']['Rating'].dropna()
              )

print(f)
# Out:
# F_onewayResult(statistic=12.79263715618054, pvalue=2.323280446259348e-20)

# %%
#Anova test for Apple App store

f = stats.f_oneway(apple_df.loc[apple_df.Genres == 'Business']['Rating'].dropna(), 
               apple_df.loc[apple_df.Genres == 'Social Networking']['Rating'].dropna(),
               apple_df.loc[apple_df.Genres == 'Games']['Rating'].dropna(),
               apple_df.loc[apple_df.Genres == 'Photo & Video']['Rating'].dropna(),
               apple_df.loc[apple_df.Genres == 'Lifestyle']['Rating'].dropna(),
               apple_df.loc[apple_df.Genres == 'Finance']['Rating'].dropna(),
               apple_df.loc[apple_df.Genres == 'Education']['Rating'].dropna(),
               apple_df.loc[apple_df.Genres == 'Medical']['Rating'].dropna(),
               apple_df.loc[apple_df.Genres == 'Utilities']['Rating'].dropna(),
               apple_df.loc[apple_df.Genres == 'Productivity']['Rating'].dropna()
              )

print(f)
# Out:
# F_onewayResult(statistic=21.399979775131815, pvalue=5.3239138531036584e-36)

# %%
# Checking basic statistics: the value count, mean, standard deviation, minimum, maximum, and 25th, 50th, and 75th quantiles for the data in the Rating column.
google_df["Rating"].describe()
# Out:
# count    8196.000000
# mean        4.173243
# std         0.536625
# min         1.000000
# 25%         4.000000
# 50%         4.300000
# 75%         4.500000
# max         5.000000
# Name: Rating, dtype: float64

# %%
apple_df["Rating"].describe()
# Out:
# count    7197.000000
# mean        3.526956
# std         1.517948
# min         0.000000
# 25%         3.500000
# 50%         4.000000
# 75%         4.500000
# max         5.000000
# Name: Rating, dtype: float64

# %% [markdown]
# ##Recategorizing Google and Apple stores ( Youqing's code)
# google play store re-categorization:
# Game: Games
#
# Education: Education, Books & Reference, Libraries & Demo
#
# Entertainment: Entertainment, Events, Social, Sports, News & Magazines
#
# Health & Fitness: Health & Fitness, Medical
#
# Photo & Video: Photography, Video Players
#
# Productivity: Productivity, Art & Design, Business
#
# Utilities: Tools, Communication, Personalization, Weather, Maps & Navigation, Finance
#
# Other (in common): Shopping, Travel & Local, Lifestyle, Food & Drink
#
# Other (unique): Auto & Vehicles, Beauty, Comics, Dating, House & Home, Parenting
#
# need spliting: Family
#
# apple store re-categorization:
# Game: Games
#
# Education: Education, Book, Reference
#
# Entertainment: Entertainment, Social Networking, Sports, News
#
# Health & Fitness: Health & Fitness, Medical
#
# Photo & Video: Photo & Video
#
# Productivity: Productivity, Business
#
# Utililies: Utililies, Weather, Navigation, Finance
#
# Other: (in common) Shopping, Travel, Business, Lifestyle, Food & Drink
#
# Other: (unique) Music, Catalogs

# %%
apple_df["Genres"].unique()
# Out:
# array(['Games', 'Productivity', 'Weather', 'Shopping', 'Reference',
#        'Finance', 'Music', 'Utilities', 'Travel', 'Social Networking',
#        'Sports', 'Business', 'Health & Fitness', 'Entertainment',
#        'Photo & Video', 'Navigation', 'Education', 'Lifestyle',
#        'Food & Drink', 'News', 'Book', 'Medical', 'Catalogs'],
#       dtype=object)

# %%
google_df["Price"] = pd.to_numeric(google_df["Price"]).map("{:.1f}".format)
google_df = google_df.rename(columns={"Size":"Size (M)"})
google_df["Category"] = google_df["Category"].str.title()
google_df["Category"] = google_df["Category"].replace({"_And_":" & ","_":" "},regex=True)
google_df = google_df.reset_index(drop=True)
google_df.head()
# Out:
#                                                  App      Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  Art & Design     4.1
# 1                                Coloring book moana  Art & Design     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  Art & Design     4.7
# 3                              Sketch - Draw & Paint  Art & Design     4.5
# 4              Pixel Draw - Number Art Coloring Book  Art & Design     4.3
#
#    Reviews  Size (M)    Installs  Type Price                     Genres
# 0      159      19.0     10000.0  Free   0.0               Art & Design
# 1      967      14.0    500000.0  Free   0.0  Art & Design;Pretend Play
# 2    87510       8.7   5000000.0  Free   0.0               Art & Design
# 3   215644      25.0  50000000.0  Free   0.0               Art & Design
# 4      967       2.8    100000.0  Free   0.0    Art & Design;Creativity

# %%
google_df["Category"].unique()
# Out:
# array(['Art & Design', 'Auto & Vehicles', 'Beauty', 'Books & Reference',
#        'Business', 'Comics', 'Communication', 'Dating', 'Education',
#        'Entertainment', 'Events', 'Finance', 'Food & Drink',
#        'Health & Fitness', 'House & Home', 'Libraries & Demo',
#        'Lifestyle', 'Game', 'Family', 'Medical', 'Social', 'Shopping',
#        'Photography', 'Sports', 'Travel & Local', 'Tools',
#        'Personalization', 'Productivity', 'Parenting', 'Weather',
#        'Video Players', 'News & Magazines', 'Maps & Navigation'],
#       dtype=object)

# %%
google_df["New Genres"]=""
google_df.loc[google_df["Category"]=="Game",["New Genres"]]="Games"

google_df.loc[(google_df["Category"]=="Education")|
           (google_df["Category"]=="Books & Reference")|
           (google_df["Category"]=="Libraries & Demo"),["New Genres"]]="Education"

google_df.loc[(google_df["Category"]=="Entertainment")|
           (google_df["Category"]=="Events")|
           (google_df["Category"]=="Social")|
           (google_df["Category"]=="Sports")|
           (google_df["Category"]=="News & Magazines"),["New Genres"]]="Entertainment"

google_df.loc[(google_df["Category"]=="Video Players")|
           (google_df["Category"]=="Photography"),["New Genres"]]="Photo & Video"

google_df.loc[(google_df["Category"]=="Tools")|
           (google_df["Category"]=="Communication")|
           (google_df["Category"]=="Personalization")|
           (google_df["Category"]=="Weather")|
           (google_df["Category"]=="Maps & Navigation")|
           (google_df["Category"]=="Finance"),["New Genres"]]="Utilities"

google_df.loc[(google_df["Category"]=="Productivity")|
           (google_df["Category"]=="Art & Design")|
           (google_df["Category"]=="Business"),["New Genres"]]="Productivity"

google_df.loc[(google_df["Category"]=="Health & Fitness")|
           (google_df["Category"]=="Medical"),["New Genres"]]="Health & Fitness"

google_df["New Genres"].unique()
# Out:
# array(['Productivity', '', 'Education', 'Utilities', 'Entertainment',
#        'Health & Fitness', 'Games', 'Photo & Video'], dtype=object)

# %%
categories = ["Education", "Entertainment", "Health & Fitness", "Games", "Productivity", "Photo & Video", "Utilities"]
games = google_df.loc[google_df["New Genres"]=="Games"]["Genres"]

family = google_df.loc[google_df["Category"]=="Family"]["Genres"].str.split(";", expand=True)[0].to_frame()

family[0] = family[0].replace({"Educational":"Education"})

for index, row in family.iterrows():
    if row.isin(categories).any():
        google_df.iloc[index,8]=row[0]
    elif row.isin(games).any():
        google_df.iloc[index,8]="Games"
    elif row[0] == "Art & Design":
        google_df.iloc[index,8]="Productivity"
    elif row[0] == "Video Players & Editors":
        google_df.iloc[index,8]="Photo & Video"
    elif row[0] == "Communication":
        google_df.iloc[index,8]="Utilities"
    elif row[0] == "Books & Reference":
        google_df.iloc[index,8]="Education"

google_df.loc[google_df["New Genres"]=="",["New Genres"]]="Other"

google_cat = google_df.groupby("New Genres").count().sort_values("App",ascending=False)

google_cat
# Out:
#                    App  Category  Rating  Reviews  Size (M)  Installs  Type  \
# New Genres
# Other             3233      3233    2785     3233      2935      3233  3232
# Utilities         2073      2073    1764     2073      1786      2073  2073
# Entertainment      984       984     814      984       796       984   984
# Games              959       959     912      959       873       959   959
# Productivity       858       858     625      858       729       858   858
# Health & Fitness   683       683     534      683       600       683   683
# Photo & Video      444       444     411      444       349       444   444
# Education          425       425     351      425       364       425   425
#
#                   Price  Genres
# New Genres
# Other              3233    3233
# Utilities          2073    2073
# Entertainment       984     984
# Games               959     959
# Productivity        858     858
# Health & Fitness    683     683
# ...

# %%
apple_df["New Genres"]=""
apple_df.loc[apple_df["Genres"]=="Games",["New Genres"]]="Games"

apple_df.loc[(apple_df["Genres"]=="Education")|
          (apple_df["Genres"]=="Book")|
          (apple_df["Genres"]=="Reference"),["New Genres"]]="Education"

apple_df.loc[(apple_df["Genres"]=="Entertainment")|
          (apple_df["Genres"]=="Social Networking")|
          (apple_df["Genres"]=="Sports")|
          (apple_df["Genres"]=="News"),["New Genres"]]="Entertainment"

apple_df.loc[apple_df["Genres"]=="Photo & Video",["New Genres"]]="Photo & Video"
apple_df.loc[(apple_df["Genres"]=="Utilities")|
          (apple_df["Genres"]=="Weather")|
          (apple_df["Genres"]=="Navigation")|
          (apple_df["Genres"]=="Finance"),["New Genres"]]="Utilities"

apple_df.loc[(apple_df["Genres"]=="Productivity")|
          (apple_df["Genres"]=="Business"),["New Genres"]]="Productivity"

apple_df.loc[(apple_df["Genres"]=="Health & Fitness")|
          (apple_df["Genres"]=="Medical"),["New Genres"]]="Health & Fitness"

apple_df.loc[apple_df["New Genres"]=="",["New Genres"]]="Other"

apple_cat = apple_df.groupby("New Genres").count().sort_values("App",ascending=False)
apple_cat
# Out:
#                    App  Price  Rating Count  Rating  Genres  Size (M)  Type
# New Genres
# Games             3862   3862          3862    3862    3862      3862  3862
# Entertainment      891    891           891     891     891       891   891
# Education          629    629           629     629     629       629   629
# Other              558    558           558     558     558       558   558
# Utilities          470    470           470     470     470       470   470
# Photo & Video      349    349           349     349     349       349   349
# Productivity       235    235           235     235     235       235   235
# Health & Fitness   203    203           203     203     203       203   203

# %% [markdown]
# ## App ratings across categories

# %% [markdown]
# Using histogram to show distribution of the wide array

# %%
from scipy import stats as stats

# Using GroupBy in order to separate the data into fields according to "New Genres" and resetting the index

groups = google_df.groupby('New Genres').filter(lambda x: len(x) > 286).reset_index()
graphs = groups['Rating'].hist(by=groups['New Genres'],  figsize=(22,22), rwidth = 0.9)

plt.savefig("fig3.png")

# %%
groups = apple_df.groupby('New Genres').filter(lambda x: len(x) > 100).reset_index()
graphs = groups['Rating'].hist(by=groups['New Genres'],  figsize=(20,20), rwidth = 0.9, color = 'black')

plt.savefig("fig4.png")
